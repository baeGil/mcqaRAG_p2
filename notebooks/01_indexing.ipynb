# %%
import os, sys
sys.path.append("..")

# %%
from src.index import process_and_index_directory, process_file, get_chunker, get_document_converter
from src.config import ConfigLoader

# %%
from src.config import config

# %%
doc_dir = "./doc_folder_2"

os.listdir(doc_dir)
# Out:
# ['Public003.pdf',
#  'Public002.pdf',
#  'Public001.pdf',
#  'Public005.pdf',
#  'Public004.pdf']

# %%
# config = ConfigLoader("../config.yaml")
# chunker = get_chunker(config=config)
# pdf_pipeline_options = config.get_pdf_pipeline_options()
# converter = get_document_converter(pdf_pipeline_options)

# %%
# files = os.listdir(doc_dir)

# %%
# docs = process_file(f"{doc_dir}/{files[0]}", converter=converter, chunker=chunker, namespace="viettel")

# %%
# len(docs)

# %%
# for doc in docs:
#     print("============= Doc: {}, Page no: {} =============".format(doc.metadata["source"], doc.metadata["page_no"]))
#     print(doc.page_content)
#     print("")

# %% [markdown]
# # Processing whole folder

# %%
config.set("database", "collection_name", "doc_2_db")

# %%
process_and_index_directory("./doc_folder_2", drop_existing=True, config=config)
# Out:
# 2025-10-18 14:07:08,070 - src.index - INFO - Found 5 files to process with HNSW indexing
# 2025-10-18 14:07:08,070 - INFO - Found 5 files to process with HNSW indexing
# 2025-10-18 14:07:10,608 - INFO - Collection 'doc_2_db' dropped
# 2025-10-18 14:07:10,611 - INFO - Use pytorch device_name: mps
# 2025-10-18 14:07:10,611 - INFO - Load pretrained SentenceTransformer: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# 2025-10-18 14:07:19,551 - src.index - INFO - Processing doc_folder_2/Public003.pdf...
# 2025-10-18 14:07:19,551 - INFO - Processing doc_folder_2/Public003.pdf...
# 2025-10-18 14:07:19,557 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-18 14:07:19,573 - INFO - Going to convert document batch...
# 2025-10-18 14:07:19,574 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 68e059f3e75bb40d4b4d82a1df76f3d7
# 2025-10-18 14:07:19,575 - INFO - Accelerator device: 'mps'
# 2025-10-18 14:07:23,933 - INFO - Accelerator device: 'mps'
# 2025-10-18 14:07:26,187 - INFO - Accelerator device: 'mps'
# 2025-10-18 14:07:26,806 - INFO - Processing document Public003.pdf
# 2025-10-18 14:07:43,546 - INFO - Finished converting document Public003.pdf in 23.99 sec.
# Token indices sequence length is longer than the specified maximum sequence length for this model (546 > 512). Running this sequence through the model will result in indexing errors
# 2025-10-18 14:07:44,345 - src.index - INFO - Processed doc_folder_2/Public003.pdf: 40 chunks
# 2025-10-18 14:07:44,345 - INFO - Processed doc_folder_2/Public003.pdf: 40 chunks
# 2025-10-18 14:07:44,347 - src.index - INFO - Processing doc_folder_2/Public002.pdf...
# 2025-10-18 14:07:44,347 - INFO - Processing doc_folder_2/Public002.pdf...
# 2025-10-18 14:07:44,349 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-18 14:07:44,353 - INFO - Going to convert document batch...
# 2025-10-18 14:07:44,354 - INFO - Processing document Public002.pdf
# 2025-10-18 14:07:50,151 - INFO - Finished converting document Public002.pdf in 5.80 sec.
# 2025-10-18 14:07:50,256 - src.index - INFO - Processed doc_folder_2/Public002.pdf: 40 chunks
# 2025-10-18 14:07:50,256 - INFO - Processed doc_folder_2/Public002.pdf: 40 chunks
# 2025-10-18 14:07:50,256 - src.index - INFO - Processing doc_folder_2/Public001.pdf...
# 2025-10-18 14:07:50,256 - INFO - Processing doc_folder_2/Public001.pdf...
# 2025-10-18 14:07:50,257 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-18 14:07:50,262 - INFO - Going to convert document batch...
# 2025-10-18 14:07:50,262 - INFO - Processing document Public001.pdf
# 2025-10-18 14:07:55,673 - INFO - Finished converting document Public001.pdf in 5.42 sec.
# 2025-10-18 14:07:56,323 - src.index - INFO - Processed doc_folder_2/Public001.pdf: 49 chunks
# 2025-10-18 14:07:56,323 - INFO - Processed doc_folder_2/Public001.pdf: 49 chunks
# 2025-10-18 14:07:56,324 - src.index - INFO - Processing doc_folder_2/Public005.pdf...
# 2025-10-18 14:07:56,324 - INFO - Processing doc_folder_2/Public005.pdf...
# 2025-10-18 14:07:56,325 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-18 14:07:56,329 - INFO - Going to convert document batch...
# 2025-10-18 14:07:56,330 - INFO - Processing document Public005.pdf
# 2025-10-18 14:08:00,658 - INFO - Finished converting document Public005.pdf in 4.33 sec.
# 2025-10-18 14:08:00,768 - src.index - INFO - Processed doc_folder_2/Public005.pdf: 27 chunks
# 2025-10-18 14:08:00,768 - INFO - Processed doc_folder_2/Public005.pdf: 27 chunks
# 2025-10-18 14:08:00,769 - src.index - INFO - Processing doc_folder_2/Public004.pdf...
# 2025-10-18 14:08:00,769 - INFO - Processing doc_folder_2/Public004.pdf...
# 2025-10-18 14:08:00,770 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-18 14:08:00,774 - INFO - Going to convert document batch...
# 2025-10-18 14:08:00,774 - INFO - Processing document Public004.pdf
# 2025-10-18 14:08:03,756 - INFO - Finished converting document Public004.pdf in 2.99 sec.
# 2025-10-18 14:08:03,931 - src.index - INFO - Processed doc_folder_2/Public004.pdf: 27 chunks
# 2025-10-18 14:08:03,931 - INFO - Processed doc_folder_2/Public004.pdf: 27 chunks
# 2025-10-18 14:08:03,932 - src.index - INFO - Indexing 183 documents with HNSW...
# 2025-10-18 14:08:03,932 - INFO - Indexing 183 documents with HNSW...
# 2025-10-18 14:08:08,794 - INFO - Added 183 documents with HNSW indexing
# 2025-10-18 14:08:08,796 - src.index - INFO - Successfully indexed 183 documents with HNSW indexing
# 2025-10-18 14:08:08,796 - INFO - Successfully indexed 183 documents with HNSW indexing

# %%
# config.set("database", "collection_name", "doc_2_db")

# %%
# process_and_index_directory("./doc_folder_2", drop_existing=True, config=config)
